# %% [markdown]
# ### Experiment 2: Maximum Likelihood and Maximum A Posteriori Parameter Estimation for Gaussian Models

# %% [markdown]
# Refs:
# - max likelihood estimation of gaussian distribution https://codeskiller.codingblocks.com/library/articles/maximum-likelihood-estimation-of-gaussian-distribution
# - MAP https://machinelearningmastery.com/maximum-a-posteriori-estimation/
# - https://medium.com/@amannagrawall002/maximum-likelihood-estimation-parameter-estimation-technique-machine-learning-f7acb3b6ca89
# - http://jrmeyer.github.io/machinelearning/2017/08/18/mle.html
# - https://www.statlect.com/fundamentals-of-statistics/normal-distribution-maximum-likelihood
# - https://www.statlect.com/fundamentals-of-statistics/maximum-likelihood
# - https://www.statlect.com/probability-distributions/normal-distribution
# - https://www.statlect.com/glossary/probability-density-function
# - https://www.statlect.com/glossary/IID-sequence
# - gaussian mixture model: https://scikit-learn.org/stable/modules/mixture.html
# - gaussian process model: https://towardsdatascience.com/gaussian-process-models-7ebce1feb83d/
# - https://distill.pub/2019/visual-exploration-gaussian-processes/
# -
