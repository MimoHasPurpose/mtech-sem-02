# %% [markdown]
# ### Experiment 8: Unsupervised pattern clustering  using K-Means and vector quantization

# %% [markdown]
# https://ocw.mit.edu/courses/6-345-automatic-speech-recognition-spring-2003/03cf90ad84bcc6971e4fc8bf26c6fee3_lecture6new.pdf
# https://medium.com/@udbhavkush4/demystifying-learning-vector-quantization-a-step-by-step-guide-with-code-implementation-from-ea3c4ab5330e

# %% [markdown]
# https://www.youtube.com/watch?v=8LifJN7oFTM&pp=ygUidmVjdG9yIHF1YW50aXphdGlvbiBhbmQgY2x1c3RlcmluZw%3D%3D
