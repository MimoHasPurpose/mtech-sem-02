# %% [markdown]
# ### Experiment 7: kernel based support vector machine using polynomail and RBF kernels

# %% [markdown]
# https://medium.com/@abhishekjainindore24/svm-kernels-and-its-type-dfc3d5f2dcd8
